# %%
from pystac import Item
from odc.stac import load

# %%
item = Item.from_file("https://s3.ap-southeast-2.amazonaws.com/files.auspatious.com/ghrsst/20231101090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.stac-item.json")
data = load([item], chunks={})
data
# Out:
# <xarray.Dataset>
# Dimensions:           (latitude: 17999, longitude: 36000, time: 1)
# Coordinates:
#   * latitude          (latitude) float64 -89.99 -89.98 -89.97 ... 89.98 89.99
#   * longitude         (longitude) float64 -180.0 -180.0 -180.0 ... 180.0 180.0
#     spatial_ref       int32 4326
#   * time              (time) datetime64[ns] 2023-11-01
# Data variables:
#     analysed_sst      (time, latitude, longitude) int16 dask.array<chunksize=(1, 17999, 36000), meta=np.ndarray>
#     analysis_error    (time, latitude, longitude) int16 dask.array<chunksize=(1, 17999, 36000), meta=np.ndarray>
#     mask              (time, latitude, longitude) int8 dask.array<chunksize=(1, 17999, 36000), meta=np.ndarray>
#     sea_ice_fraction  (time, latitude, longitude) int8 dask.array<chunksize=(1, 17999, 36000), meta=np.ndarray>
#     sst_anomaly       (time, latitude, longitude) int16 dask.array<chunksize=(1, 17999, 36000), meta=np.ndarray>

# %%
data.squeeze().analysed_sst.plot.imshow(cmap='magma', robust=True, size=10)
